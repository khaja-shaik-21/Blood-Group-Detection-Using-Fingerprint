# %%
# !pip install torch torchvision matplotlib scikit-learn kaggle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 35.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-000bf19e-0c57-4980-b4d2-eb154a546964" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-000bf19e-0c57-4980-b4d2-eb154a546964">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# 401 - Unauthorized - Unauthenticated

# %%
! kaggle datasets download -d rajumavinmar/finger-print-based-blood-group-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rajumavinmar/finger-print-based-blood-group-dataset
# License(s): unknown
# ...
#  96% 56.0M/58.1M [00:03<00:00, 23.8MB/s]
# 100% 58.1M/58.1M [00:03<00:00, 16.1MB/s]

# %%
! unzip finger-print-based-blood-group-dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset_blood_group/A-/cluster_1_3319.BMP
#   inflating: dataset_blood_group/A-/cluster_1_3326.BMP
#   inflating: dataset_blood_group/A-/cluster_1_3329.BMP
#   inflating: dataset_blood_group/A-/cluster_1_3350.BMP
#   inflating: dataset_blood_group/A-/cluster_1_3353.BMP
#   inflating: dataset_blood_group/A-/cluster_1_3356.BMP
#   inflating: dataset_blood_group/A-/cluster_1_3372.BMP
#   inflating: dataset_blood_group/A-/cluster_1_3381.BMP
#   inflating: dataset_blood_group/A-/cluster_1_3394.BMP
#   inflating: dataset_blood_group/A-/cluster_1_3404.BMP
#   inflating: dataset_blood_group/A-/cluster_1_3409.BMP
#   inflating: dataset_blood_group/A-/cluster_1_3414.BMP
#   inflating: dataset_blood_group/A-/cluster_1_3416.BMP
#   inflating: dataset_blood_group/A-/cluster_1_3421.BMP
#   inflating: dataset_blood_group/A-/cluster_1_3423.BMP
#   inflating: dataset_blood_group/A-/cluster_1_3424.BMP
# ...

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

class CNNClassifier(nn.Module):
    def __init__(self, num_classes):
        super(CNNClassifier, self).__init__()

        # Enhanced Convolutional Layers
        self.features = nn.Sequential(
            # First Convolutional Block
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            # Second Convolutional Block
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            # Third Convolutional Block
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )

        # Adaptive Pooling and Fully Connected Layers
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d((7, 7)),
            nn.Flatten(),
            nn.Linear(128 * 7 * 7, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

def train_model(model, train_loader, val_loader, test_loader, device, epochs=100):
    # Loss and Optimizer Configuration
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(
        model.parameters(),
        lr=0.001,
        weight_decay=1e-4
    )

    # Learning Rate Scheduler
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',
        patience=5,
        factor=0.5
    )

    # Metrics Tracking
    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []

    best_val_loss = float('inf')

    for epoch in range(epochs):
        # Training Phase
        model.train()
        train_loss, train_correct = 0.0, 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            train_correct += (predicted == labels).sum().item()

        # Validation Phase
        model.eval()
        val_loss, val_correct = 0.0, 0

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                val_correct += (predicted == labels).sum().item()

        # Compute Metrics
        train_epoch_loss = train_loss / len(train_loader)
        train_epoch_acc = train_correct / len(train_loader.dataset)
        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_acc = val_correct / len(val_loader.dataset)

        train_losses.append(train_epoch_loss)
        train_accuracies.append(train_epoch_acc)
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_acc)

        # Learning Rate Scheduling
        scheduler.step(val_epoch_loss)

        # Model Checkpointing
        if val_epoch_loss < best_val_loss:
            best_val_loss = val_epoch_loss
            torch.save(model.state_dict(), 'best_model.pth')

        # Logging
        print(f"Epoch {epoch+1}/{epochs}")
        print(f"Train Loss: {train_epoch_loss:.4f}, Train Acc: {train_epoch_acc:.4f}")
        print(f"Val Loss: {val_epoch_loss:.4f}, Val Acc: {val_epoch_acc:.4f}")

    # Test Evaluation
    model.eval()
    test_correct, test_total = 0, 0
    all_preds, all_labels = [], []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)

            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    test_accuracy = test_correct / test_total
    print(f"Test Accuracy: {test_accuracy:.4f}")

    # Visualization
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Val Loss')
    plt.title('Loss Progression')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Train Accuracy')
    plt.plot(val_accuracies, label='Val Accuracy')
    plt.title('Accuracy Progression')
    plt.legend()

    plt.tight_layout()
    plt.show()

    # Confusion Matrix
    cm = confusion_matrix(all_labels, all_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap='Blues')
    plt.title('Confusion Matrix')
    plt.show()

def main():
    # Device Configuration
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")

    # Image Transformations
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.485, 0.456, 0.406],
            std=[0.229, 0.224, 0.225]
        )
    ])

    # Dataset Path (Update with your actual path)
    dataset_path = '/content/dataset_blood_group'

    # Load Dataset
    dataset = datasets.ImageFolder(
        root=dataset_path,
        transform=transform
    )

    # Print Dataset Information
    print("Classes:", dataset.classes)
    print("Total Images:", len(dataset))

    # Dataset Splitting
    train_size = int(0.7 * len(dataset))
    val_size = int(0.15 * len(dataset))
    test_size = len(dataset) - train_size - val_size

    train_dataset, val_dataset, test_dataset = random_split(
        dataset, [train_size, val_size, test_size]
    )

    # DataLoaders
    train_loader = DataLoader(
        train_dataset,
        batch_size=32,
        shuffle=True,
        num_workers=4,
        pin_memory=True
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=32,
        shuffle=False,
        num_workers=4,
        pin_memory=True
    )
    test_loader = DataLoader(
        test_dataset,
        batch_size=32,
        shuffle=False,
        num_workers=4,
        pin_memory=True
    )

    # Model Initialization
    num_classes = len(dataset.classes)
    model = CNNClassifier(num_classes=num_classes).to(device)

    # Training
    train_model(
        model,
        train_loader,
        val_loader,
        test_loader,
        device,
        epochs=50
    )

if __name__ == '__main__':
    main()
# Out:
# Using device: cuda
# Classes: ['A+', 'A-', 'AB+', 'AB-', 'B+', 'B-', 'O+', 'O-']
# Total Images: 6000
# Epoch 1/50
# Train Loss: 1.1076, Train Acc: 0.5883
# Val Loss: 0.9049, Val Acc: 0.6744
# Epoch 2/50
# Train Loss: 0.6168, Train Acc: 0.7681
# Val Loss: 0.8397, Val Acc: 0.7067
# Epoch 3/50
# Train Loss: 0.5178, Train Acc: 0.8043
# Val Loss: 0.6860, Val Acc: 0.7489
# Epoch 4/50
# Train Loss: 0.4863, Train Acc: 0.8214
# Val Loss: 0.3788, Val Acc: 0.8544
# Epoch 5/50
# Train Loss: 0.4364, Train Acc: 0.8488
# Val Loss: 0.3500, Val Acc: 0.8556
# Epoch 6/50
# Train Loss: 0.4195, Train Acc: 0.8490
# Val Loss: 0.3802, Val Acc: 0.8444
# Epoch 7/50
# Train Loss: 0.4231, Train Acc: 0.8443
# Val Loss: 0.6256, Val Acc: 0.7689
# Epoch 8/50
# Train Loss: 0.3715, Train Acc: 0.8645
# Val Loss: 0.3448, Val Acc: 0.8800
# Epoch 9/50
# Train Loss: 0.3522, Train Acc: 0.8707
# Val Loss: 0.4376, Val Acc: 0.8233
# Epoch 10/50
# Train Loss: 0.3366, Train Acc: 0.8719
# Val Loss: 0.3069, Val Acc: 0.8644
# ...

# %%
import torch
from torchvision import transforms
from PIL import Image

# Define the mapping of class indices to blood groups
class_mapping = {
    0: "A+",
    1: "A-",
    2: "AB+",
    3: "AB-",
    4: "B+",
    5: "B-",
    6: "O+",
    7: "O-"
}

def predict_blood_group(model, image_path, device):
    # Load and preprocess the image
    transform = transforms.Compose([
        transforms.Resize((224, 224)),  # Resize to match model input size
        transforms.ToTensor(),           # Convert image to tensor
        transforms.Normalize(
            mean=[0.485, 0.456, 0.406], # Normalize based on ImageNet stats
            std=[0.229, 0.224, 0.225]
        )
    ])

    # Open the BMP image
    image = Image.open(image_path).convert('RGB')  # Ensure it's in RGB format
    image = transform(image).unsqueeze(0)          # Add batch dimension

    # Move the image to the appropriate device (CPU or GPU)
    image = image.to(device)

    # Set the model to evaluation mode
    model.eval()

    with torch.no_grad():
        # Get the model's prediction
        outputs = model(image)
        _, predicted = torch.max(outputs, 1)

    # Get the predicted blood group
    predicted_class = predicted.item()
    blood_group = class_mapping[predicted_class]

    return blood_group

def main():
    # Device configuration
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load the best model
    model = CNNClassifier(num_classes=8)  # Adjust based on your dataset
    model.load_state_dict(torch.load('best_model.pth'))
    model.to(device)

    # Path to the BMP image you want to predict (update with your actual path)
    image_path = '/content/IMG_0735 (11).bmp'  # Make sure this is a BMP file

    # Predict the blood group
    blood_group = predict_blood_group(model, image_path, device)

    print(f"The predicted blood group is: {blood_group}")

if __name__ == '__main__':
    main()
# Out:
# The predicted blood group is: AB-
# <ipython-input-10-23434fac987f>:55: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
def main():
    # Device Configuration
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")

    # Image Transformations
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.485, 0.456, 0.406],
            std=[0.229, 0.224, 0.225]
        )
    ])

    # Dataset Path (Update with your actual path)
    dataset_path = '/content/dataset_blood_group'

    # Load Dataset
    dataset = datasets.ImageFolder(
        root=dataset_path,
        transform=transform
    )

    # Print Dataset Information
    print("Classes:", dataset.classes)
    print("Total Images:", len(dataset))

    # Dataset Splitting
    train_size = int(0.7 * len(dataset))
    val_size = int(0.15 * len(dataset))
    test_size = len(dataset) - train_size - val_size

    train_dataset, val_dataset, test_dataset = random_split(
        dataset, [train_size, val_size, test_size]
    )

    # DataLoaders
    train_loader = DataLoader(
        train_dataset,
        batch_size=32,
        shuffle=True,
        num_workers=4,
        pin_memory=True
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=32,
        shuffle=False,
        num_workers=4,
        pin_memory=True
    )
    test_loader = DataLoader(
        test_dataset,
        batch_size=32,
        shuffle=False,
        num_workers=4,
        pin_memory=True
    )

    # Model Initialization
    num_classes = len(dataset.classes)
    model = CNNClassifier(num_classes=num_classes).to(device)

    # Training
    train_model(
        model,
        train_loader,
        val_loader,
        test_loader,
        device,
        epochs=50
    )

if __name__ == '__main__':
    main()
# Out:
# Using device: cuda
# Classes: ['A+', 'A-', 'AB+', 'AB-', 'B+', 'B-', 'O+', 'O-']
# Total Images: 6000
# Epoch 1/50
# Train Loss: 1.1139, Train Acc: 0.5786
# Val Loss: 0.9956, Val Acc: 0.6311
# Epoch 2/50
# Train Loss: 0.6202, Train Acc: 0.7717
# Val Loss: 0.6405, Val Acc: 0.7578
# Epoch 3/50
# Train Loss: 0.5620, Train Acc: 0.7962
# Val Loss: 0.3391, Val Acc: 0.8789
# Epoch 4/50
# Train Loss: 0.4945, Train Acc: 0.8160
# Val Loss: 0.4705, Val Acc: 0.8000
# Epoch 5/50
# Train Loss: 0.4550, Train Acc: 0.8417
# Val Loss: 0.3445, Val Acc: 0.8756
# Epoch 6/50
# Train Loss: 0.4183, Train Acc: 0.8462
# Val Loss: 0.4596, Val Acc: 0.8422
# Epoch 7/50
# Train Loss: 0.3879, Train Acc: 0.8579
# Val Loss: 0.3522, Val Acc: 0.8578
# Epoch 8/50
# Train Loss: 0.3814, Train Acc: 0.8633
# Val Loss: 0.4067, Val Acc: 0.8344
# Epoch 9/50
# Train Loss: 0.3700, Train Acc: 0.8598
# Val Loss: 0.5812, Val Acc: 0.7722
# Epoch 10/50
# Train Loss: 0.2911, Train Acc: 0.8952
# Val Loss: 0.3608, Val Acc: 0.8656
# ...

# %%
import torch
from torchvision import transforms, datasets
from PIL import Image
import os
import random
import matplotlib.pyplot as plt

# Define the mapping of class indices to blood groups
class_mapping = {
    0: "A+",
    1: "A-",
    2: "AB+",
    3: "AB-",
    4: "B+",
    5: "B-",
    6: "O+",
    7: "O-"
}

def predict_blood_group(model, image_path, device):
    # Load and preprocess the image
    transform = transforms.Compose([
        transforms.Resize((224, 224)),  # Resize to match model input size
        transforms.ToTensor(),           # Convert image to tensor
        transforms.Normalize(
            mean=[0.485, 0.456, 0.406], # Normalize based on ImageNet stats
            std=[0.229, 0.224, 0.225]
        )
    ])

    # Open the image
    image = Image.open(image_path).convert('RGB')  # Ensure it's in RGB format
    image_tensor = transform(image).unsqueeze(0)   # Add batch dimension

    # Move the image to the appropriate device (CPU or GPU)
    image_tensor = image_tensor.to(device)

    # Set the model to evaluation mode
    model.eval()

    with torch.no_grad():
        # Get the model's prediction
        outputs = model(image_tensor)
        _, predicted = torch.max(outputs, 1)

    # Get the predicted blood group
    predicted_class = predicted.item()
    blood_group = class_mapping[predicted_class]

    return blood_group, image

def main():
    # Device configuration
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")  # Debugging: Print device info

    # Load the best model
    model = CNNClassifier(num_classes=8)  # Adjust based on your dataset
    model.load_state_dict(torch.load('best_model.pth', weights_only=True))  # Handle future warning
    model.to(device)
    print("Model loaded successfully.")  # Debugging: Ensure model is loaded

    # Path to the folder containing the images
    dataset_path = '/content/dataset_blood_group'  # Update with the folder containing the class subfolders

    # Check the contents of the dataset path to debug if it's correct
    print(f"Contents of dataset path: {os.listdir(dataset_path)}")  # Debugging: List top-level directory contents

    # List all image files in the dataset (under the subfolders)
    image_files = []

    # Iterate through each class folder and list .bmp files
    for class_folder in os.listdir(dataset_path):
        class_folder_path = os.path.join(dataset_path, class_folder)
        if os.path.isdir(class_folder_path):  # Check if it's a directory
            print(f"Found class folder: {class_folder}")  # Debugging: Print current class folder
            for img_file in os.listdir(class_folder_path):
                if img_file.lower().endswith('.bmp'):  # Case-insensitive check for .bmp files
                    image_files.append(os.path.join(class_folder_path, img_file))
                    print(f"Found image: {img_file}")  # Debugging: Print image found

    print(f"Found {len(image_files)} images.")  # Debugging: Check how many images are found

    # Check if there are at least 20 images, and adjust if necessary
    num_images_to_sample = min(20, len(image_files))  # Sample all if fewer than 20 images available
    random_images = random.sample(image_files, num_images_to_sample)

    print(f"Sampling {num_images_to_sample} images.")  # Debugging: Show how many images will be sampled

    # Create a subplot for displaying images
    plt.figure(figsize=(12, 12))
    for i, image_file in enumerate(random_images):
        blood_group, image = predict_blood_group(model, image_file, device)
        actual_label = image_file.split('/')[3]  # Extract the actual label from the file path

        # Display image
        plt.subplot(5, 4, i+1)  # Adjust subplot grid size based on number of images
        plt.imshow(image)
        plt.axis('off')

        # Display predicted and actual blood group on the image
        plt.title(f"Pred: {blood_group}\nTrue: {actual_label}")

    plt.tight_layout()
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Found image: cluster_3_3023.BMP
# Found image: cluster_3_1529.BMP
# Found image: cluster_3_406.BMP
# Found image: cluster_3_3219.BMP
# Found image: cluster_3_5814.BMP
# Found image: cluster_3_1729.BMP
# Found image: cluster_3_914.BMP
# Found image: cluster_3_2235.BMP
# Found image: cluster_3_2126.BMP
# Found image: cluster_3_2387.BMP
# Found image: cluster_3_641.BMP
# Found image: cluster_3_776.BMP
# Found image: cluster_3_412.BMP
# Found image: cluster_3_5010.BMP
# Found image: cluster_3_3012.BMP
# Found image: cluster_3_1270.BMP
# Found image: cluster_3_3267.BMP
# Found image: cluster_3_2756.BMP
# Found image: cluster_3_1496.BMP
# Found image: cluster_3_1426.BMP
# Found image: cluster_3_387.BMP
# Found image: cluster_3_2312.BMP
# Found image: cluster_3_4647.BMP
# Found image: cluster_3_1296.BMP
# Found image: cluster_3_4188.BMP
# Found image: cluster_3_3175.BMP
# Found image: cluster_3_2231.BMP
# Found image: cluster_3_1342.BMP
# ...

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

class CNNClassifier(nn.Module):
    def __init__(self, num_classes):
        super(CNNClassifier, self).__init__()

        # Enhanced Convolutional Layers
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )

        # Adaptive Pooling and Fully Connected Layers
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d((7, 7)),
            nn.Flatten(),
            nn.Linear(128 * 7 * 7, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

def train_model(model, train_loader, val_loader, test_loader, device, epochs=50):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.5)

    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []

    best_val_loss = float('inf')

    for epoch in range(epochs):
        model.train()
        train_loss, train_correct = 0.0, 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            train_correct += (predicted == labels).sum().item()

        model.eval()
        val_loss, val_correct = 0.0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                val_correct += (predicted == labels).sum().item()

        train_epoch_loss = train_loss / len(train_loader)
        train_epoch_acc = train_correct / len(train_loader.dataset)
        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_acc = val_correct / len(val_loader.dataset)

        train_losses.append(train_epoch_loss)
        train_accuracies.append(train_epoch_acc)
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_acc)

        scheduler.step(val_epoch_loss)

        if val_epoch_loss < best_val_loss:
            best_val_loss = val_epoch_loss
            torch.save(model.state_dict(), 'best_model.pth')

        print(f"Epoch {epoch+1}/{epochs}")
        print(f"Train Loss: {train_epoch_loss:.4f}, Train Acc: {train_epoch_acc:.4f}")
        print(f"Val Loss: {val_epoch_loss:.4f}, Val Acc: {val_epoch_acc:.4f}")

    model.eval()
    test_correct, test_total = 0, 0
    all_preds, all_labels = [], []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)

            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    test_accuracy = test_correct / test_total
    print(f"Test Accuracy: {test_accuracy:.4f}")

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Val Loss')
    plt.title('Loss Progression')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Train Accuracy')
    plt.plot(val_accuracies, label='Val Accuracy')
    plt.title('Accuracy Progression')
    plt.legend()

    plt.tight_layout()
    plt.show()

    cm = confusion_matrix(all_labels, all_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap='Blues')
    plt.title('Confusion Matrix')
    plt.show()

def test_with_validation_images(model, val_loader, device, class_names):
    model.eval()

    plt.figure(figsize=(12, 8))
    rows, cols = 3, 3
    idx = 0

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)

            for i in range(inputs.size(0)):
                if idx >= rows * cols:
                    break

                img = inputs[i].cpu().numpy().transpose(1, 2, 0)
                img = img * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406])
                img = np.clip(img, 0, 1)

                plt.subplot(rows, cols, idx + 1)
                plt.imshow(img)
                plt.title(f"True: {class_names[labels[i]]}\nPred: {class_names[predicted[i]]}")
                plt.axis('off')

                idx += 1

            if idx >= rows * cols:
                break

    plt.tight_layout()
    plt.show()

def test_with_unseen_data(model, test_loader, device, class_names):
    model.eval()  # Set the model to evaluation mode

    test_correct, test_total = 0, 0
    all_preds, all_labels = [], []

    # Visualize Predictions
    plt.figure(figsize=(12, 8))
    rows, cols = 3, 3  # Grid for displaying images
    idx = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)

            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            # Visualize some predictions
            for i in range(inputs.size(0)):
                if idx >= rows * cols:  # Display a limited number of images
                    break

                img = inputs[i].cpu().numpy().transpose(1, 2, 0)
                img = img * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406])  # De-normalize
                img = np.clip(img, 0, 1)

                plt.subplot(rows, cols, idx + 1)
                plt.imshow(img)
                plt.title(f"True: {class_names[labels[i]]}\nPred: {class_names[predicted[i]]}")
                plt.axis('off')

                idx += 1

            if idx >= rows * cols:
                break

    # Calculate and print test accuracy
    test_accuracy = test_correct / test_total
    print(f"Test Accuracy: {test_accuracy:.4f}")

    # Show the grid of predictions
    plt.tight_layout()
    plt.show()

    # Confusion Matrix
    cm = confusion_matrix(all_labels, all_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap='Blues', xticks_rotation=45)
    plt.title('Confusion Matrix on Test Dataset')
    plt.show()

def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")

    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    dataset_path = '/content/dataset_blood_group'
    dataset = datasets.ImageFolder(root=dataset_path, transform=transform)

    print("Classes:", dataset.classes)
    print("Total Images:", len(dataset))

    train_size = int(0.7 * len(dataset))
    val_size = int(0.15 * len(dataset))
    test_size = len(dataset) - train_size - val_size

    train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True)

    num_classes = len(dataset.classes)
    model = CNNClassifier(num_classes=num_classes).to(device)

    train_model(model, train_loader, val_loader, test_loader, device, epochs=50)

    class_names = val_loader.dataset.dataset.classes
    test_with_validation_images(model, val_loader, device, class_names)

    class_names = test_loader.dataset.dataset.classes
    test_with_unseen_data(model, test_loader, device, class_names)

if __name__ == '__main__':
    main()
# Out:
# Using device: cuda
# Classes: ['A+', 'A-', 'AB+', 'AB-', 'B+', 'B-', 'O+', 'O-']
# Total Images: 6000
# Epoch 1/50
# Train Loss: 1.1786, Train Acc: 0.5593
# Val Loss: 0.4951, Val Acc: 0.8011
# Epoch 2/50
# Train Loss: 0.6511, Train Acc: 0.7624
# Val Loss: 0.6493, Val Acc: 0.7567
# Epoch 3/50
# Train Loss: 0.5731, Train Acc: 0.7900
# Val Loss: 0.4789, Val Acc: 0.8278
# Epoch 4/50
# Train Loss: 0.4618, Train Acc: 0.8345
# Val Loss: 0.3645, Val Acc: 0.8533
# Epoch 5/50
# Train Loss: 0.4792, Train Acc: 0.8352
# Val Loss: 0.5783, Val Acc: 0.7922
# Epoch 6/50
# Train Loss: 0.4377, Train Acc: 0.8412
# Val Loss: 0.3653, Val Acc: 0.8567
# Epoch 7/50
# Train Loss: 0.3989, Train Acc: 0.8614
# Val Loss: 0.5409, Val Acc: 0.7944
# Epoch 8/50
# Train Loss: 0.4019, Train Acc: 0.8533
# Val Loss: 0.3504, Val Acc: 0.8533
# Epoch 9/50
# Train Loss: 0.3356, Train Acc: 0.8824
# Val Loss: 0.3516, Val Acc: 0.8744
# Epoch 10/50
# Train Loss: 0.3799, Train Acc: 0.8612
# Val Loss: 0.2854, Val Acc: 0.8989
# ...

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, random_split


class CNNClassifier(nn.Module):
    def __init__(self, num_classes):
        super(CNNClassifier, self).__init__()

        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )

        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d((7, 7)),
            nn.Flatten(),
            nn.Linear(128 * 7 * 7, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x


def train_model(model, train_loader, val_loader, device, epochs=50):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.5)

    best_val_loss = float('inf')

    for epoch in range(epochs):
        model.train()
        train_loss, train_correct = 0, 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            train_correct += (predicted == labels).sum().item()

        train_acc = train_correct / len(train_loader.dataset)

        model.eval()
        val_loss, val_correct = 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                val_correct += (predicted == labels).sum().item()

        val_acc = val_correct / len(val_loader.dataset)

        print(f"Epoch {epoch+1}: Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}")

        scheduler.step(val_loss)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), "/content/best_model.pth")
            print("Best model saved!")

def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    dataset_path = "/content/dataset_blood_group"

    # Transformations
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    dataset = datasets.ImageFolder(root=dataset_path, transform=transform)
    num_classes = len(dataset.classes)

    train_size = int(0.7 * len(dataset))
    val_size = int(0.15 * len(dataset))
    test_size = len(dataset) - train_size - val_size

    train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2)

    model = CNNClassifier(num_classes=num_classes).to(device)

    train_model(model, train_loader, val_loader, device, epochs=50)

    from google.colab import drive
    drive.mount('/content/drive')
    # !cp /content/best_model.pth /content/drive/MyDrive/best_model.pth
    print("Model saved to Google Drive!")

if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# Epoch 1: Train Acc: 0.5500, Val Acc: 0.7578
# Best model saved!
# Epoch 2: Train Acc: 0.7607, Val Acc: 0.7467
# Epoch 3: Train Acc: 0.7807, Val Acc: 0.8300
# Best model saved!
# Epoch 4: Train Acc: 0.8164, Val Acc: 0.8989
# Best model saved!
# Epoch 5: Train Acc: 0.8340, Val Acc: 0.8322
# Epoch 6: Train Acc: 0.8493, Val Acc: 0.8867
# Epoch 7: Train Acc: 0.8531, Val Acc: 0.8500
# Epoch 8: Train Acc: 0.8571, Val Acc: 0.8978
# Epoch 9: Train Acc: 0.8521, Val Acc: 0.8889
# Best model saved!
# Epoch 10: Train Acc: 0.8681, Val Acc: 0.8944
# Best model saved!
# Epoch 11: Train Acc: 0.8760, Val Acc: 0.9156
# Best model saved!
# Epoch 12: Train Acc: 0.8776, Val Acc: 0.8456
# Epoch 13: Train Acc: 0.8850, Val Acc: 0.9000
# Epoch 14: Train Acc: 0.8819, Val Acc: 0.8711
# Epoch 15: Train Acc: 0.8905, Val Acc: 0.8744
# Epoch 16: Train Acc: 0.8979, Val Acc: 0.8678
# Epoch 17: Train Acc: 0.9021, Val Acc: 0.9144
# Best model saved!
# Epoch 18: Train Acc: 0.9017, Val Acc: 0.8500
# ...
